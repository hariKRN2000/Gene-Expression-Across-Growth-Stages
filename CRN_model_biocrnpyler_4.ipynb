# %% [markdown]
# ### CRN compiled using BioCRNpyler

# %%
# Import all the required packages here 

from biocrnpyler import *
from bioscrape.types import Model
from bioscrape.simulator import py_simulate_model

import pandas as pd
import numpy as np
from matplotlib import style
# %config InlineBackend.figure_format = 'retina'

style.use("default")

# %matplotlib inline

# %%
# Importing experimental data

geags_data = pd.read_csv("GEAGS_data_2.csv")
#!! Don't use "time", reserved keyword.
time = geags_data["Time (min)"].to_numpy()
## ! What's A and What's B? Are there more relevant labels for these?
A1 = geags_data["A1"].to_numpy()
A2 = geags_data["A2"].to_numpy()
A3 = geags_data["A3"].to_numpy()
B1 = geags_data["B1"].to_numpy()
B2 = geags_data["B2"].to_numpy()
B3 = geags_data["B3"].to_numpy()

A12 = A1 - A1[0]
A1_non_leaky = A12[np.argwhere(A12 >= 0)]
t12 = time[len(A1_non_leaky) - 1]
time12 = np.linspace(0,t12,len(A1_non_leaky))

A22 = A2 - A2[0]
A2_non_leaky = A22[np.argwhere(A22 >= 0)]
t22 = time[len(A2_non_leaky) - 1]
time22 = np.linspace(0,t22,len(A2_non_leaky))

A32 = A3 - A3[0]
A3_non_leaky = A32[np.argwhere(A32 >= 0)]
t32 = time[len(A3_non_leaky) - 1]
time32 = np.linspace(0,t32,len(A3_non_leaky))

B12 = B1 - B1[0]
B1_non_leaky = B12[np.argwhere(B12 >= 0)]
tB12 = time[len(B1_non_leaky) - 1]
timeB12 = np.linspace(0,tB12,len(B1_non_leaky))

B22 = B2 - B2[0]
B2_non_leaky = B22[np.argwhere(B22 >= 0)]
tB22 = time[len(B2_non_leaky) - 1]
timeB22 = np.linspace(0,tB22,len(B2_non_leaky))

B32 = B3 - B3[0]
B3_non_leaky = B32[np.argwhere(B32 >= 0)]
tB32 = time[len(B3_non_leaky) - 1]
timeB32 = np.linspace(0,tB32,len(B3_non_leaky))

A_avg = (A1_non_leaky[:88] + A2_non_leaky[:88] + A3_non_leaky[:88])/3
B_avg = (B1_non_leaky[:88] + B2_non_leaky[:88] + B3_non_leaky[:88])/3
avg_fold_change = np.mean((np.max(B1_non_leaky)/np.max(A1_non_leaky),np.max(B2_non_leaky)/np.max(A2_non_leaky),np.max(B3_non_leaky)/np.max(A3_non_leaky)))
avg_fold_change
# Out:
# 10.730826930616777

# %%
# Importing growth data

OD_data = pd.read_csv("GEAGS_growth_data.csv")
time = OD_data["time(min)"].to_numpy()
OD_blank = 0.078*1 # Is this also from the CSV?
A1 = OD_data["A1"].to_numpy() - OD_blank
A2 = OD_data["A2"].to_numpy() - OD_blank
A3 = OD_data["A3"].to_numpy() - OD_blank
B1 = OD_data["B1"].to_numpy() - OD_blank
B2 = OD_data["B2"].to_numpy() - OD_blank
B3 = OD_data["B3"].to_numpy() - OD_blank

C_OD = 1e9
C1 = A1 * C_OD
C2 = A2 * C_OD
C3 = A3 * C_OD
C4 = B1 * C_OD
C5 = B2 * C_OD
C6 = B3 * C_OD

C1_max = np.max(C1)
C2_max = np.max(C2)
C3_max = np.max(C3)
C4_max = np.max(C4)
C5_max = np.max(C5)
C6_max = np.max(C6)
C_max = [C1_max, C2_max, C3_max, C4_max, C5_max, C6_max]

C1_0 = np.min(C1)
C2_0 = np.min(C2)
C3_0 = np.min(C3)
C4_0 = np.min(C4)
C5_0 = np.min(C5)
C6_0 = np.min(C6)
C_0 = [C1_0, C2_0, C3_0, C4_0, C5_0, C6_0]

k_gr = [0.01692117, 0.01527194, 0.01514989, 0.01656997, 0.01770599,
       0.01571999]
k_gr1 = k_gr[0]
k_gr2 = k_gr[1]
k_gr3 = k_gr[2]
k_gr4 = k_gr[3]
k_gr5 = k_gr[4]
k_gr6 = k_gr[5]

C_max_avg = np.mean(C_max[:3])
C_0_avg = np.mean(C_0[:3])
k_gr_avg = np.mean(k_gr[:3])

# %%
from GEAGS_data_import import *

[C, C_max, C_0, k_gr, C_max_avg, C_0_avg, k_gr_avg] = Get_OD_Data()
[A_non_leaky, time_A, B_non_leaky, time_B, avg_fold_change] = Get_FLOD_Data()

# %% [markdown]
# #### Import all the mechanisms and propensities

# %%
# from GEAGS_mechanisms import *
# Importing the mechanisms and biocrnpyler propensities in this cell 
# I wrote all the mechanism and propensities in a different file 


from GEAGS_mechanisms_4 import *

from GEAGS_propensities_4 import *

# %% [markdown]
# #### Create Growth Component

# %%
# Defining a Cell Growth component 

class CellGrowth(Component):
    """The CellGrowth Component is a component that consists of a cell counter
    and allows for cells to grow.
    """

    def __init__(self, name, attributes=None, material_type=None, **keywords):
        """Initialize a Component object
        :param name: Name of the component (str)
        :param attributes: Species attribute
        :param keywords: pass into the parent's (Component) initializer
        """
        self.species = self.set_species(name, material_type=material_type,
                                        attributes=attributes)
        super().__init__(name=name, **keywords)

    def get_species(self) -> Species:
        return self.species

    def update_species(self) -> List[Species]:
        growth_mech = self.get_mechanism('logistic_cell_growth')
        return growth_mech.update_species()

    def update_reactions(self) -> List:
        growth_mech = self.get_mechanism('logistic_cell_growth')
        return growth_mech.update_reactions(component = self, part_id = self.name)

# %% [markdown]
# ### Create the 'Mixture' class that contains all the components and the mechanisms, which is then compiled by biocrnpyler

# %%
class BacterialMixture(Mixture):
    """A Model for gene expression in growing bacteria. The mixture models resources such as 
    ribosomes, polymerases, endonucleases, nucleotides, and ATP (all labelled as Machinery).

    This model includes cell growth which model the innate loading effects in the cell.
    """
    def __init__(self, name = "bacterialmixture", rnap = "RNAP", sigma = "sigma", ribosome = "Ribo", rnaase = "RNAase", 
                 nucleotide = "NT", aminoacid = "AA", tRNA = "tRNA", unfolded_protein = "unfolded_protein", 
                 Et = "Et", peptide_chain = "peptide_chain", protease = "protease", degtag = True,
                 cell_count = None, **kwargs):
        """Initializes a BacterialMixture instance.

        :param name: name of the mixture, default: bacterialmixture
        :param rnap: name of the RNA polymerase, default: RNAP
        :param sigma: name of the sigma factor, default: sigma
        :param ribosome: name of the ribosome, default: Ribo
        :param rnaase: name of the Ribonuclease, default: RNAase
        :param nucelotide: name of the nucleotide representing species, default: NT
        :param aminoacid: name of the amino acid representing species, default: AA
        :param tRNA: name of the transfer RNA representing species, default: tRNA
        :param Et: name of the tRNA synthetase enzyme
        :param unfolded_protein: name of the unfolded protein representing species, default: unfolded_protein
        :param peptide_chain: name of the species representing all the protein that has been degraded
        :param cell_count: Species representing cell count
        :param degtag: This parameter takes in True or False. True by default. Condition to set deg-tag or not include it
        :param kwargs: keywords passed into the parent Class (Mixture)
        """
        Mixture.__init__(self, name = name, **kwargs)

        # Create Components for TxTl machinery
        self.rnap = Protein(rnap)
        self.sigma = Protein(sigma)
        self.ribosome = Protein(ribosome)
        self.rnaase = Protein(rnaase)
        self.nucleotide = Protein(nucleotide)
        self.aminoacid = Protein(aminoacid)
        self.tRNA = Protein(tRNA)
        self.Et = Protein(Et)
        self.unfolded_protein = Protein(unfolded_protein)
        self.peptide_chain = Protein(peptide_chain)
        self.protease = Protein(protease)
        

        
        self.rnap.add_attribute("machinery")
        self.sigma.add_attribute("machinery")
        self.ribosome.add_attribute("machinery")
        self.rnaase.add_attribute("machinery")
        self.nucleotide.add_attribute("units")
        self.aminoacid.add_attribute("units0tl")
        self.tRNA.add_attribute("machinery")
        self.Et.add_attribute("machinery")
        self.unfolded_protein.add_attribute("degtag")
        self.peptide_chain.add_attribute("peptide")
        self.protease.add_attribute("machinery")
        

        
        self.cell_count = CellGrowth("cell_count")
        self.cell_count.add_attribute("count")
        default_components = [
            self.rnap, self.sigma, self.ribosome, self.rnaase,
            self.nucleotide, self.aminoacid,  
            self.tRNA, self.Et,
            self.unfolded_protein, self.peptide_chain, self.protease,
            self.cell_count
        ]
        self.add_components(default_components)

        self.degtag = degtag

        #Create TxTl Mechansisms
        mech_tx = BacterialTranscription(rnap = self.rnap.get_species(), sigma = self.sigma.get_species(),
                                         nucleotide = self.nucleotide.get_species(),
                                         cell_count = self.cell_count.get_species())
        mech_tl = BacterialTranslation(ribosome = self.ribosome.get_species(), aminoacid = self.aminoacid.get_species(), 
                                       tRNA = self.tRNA.get_species(),
                                       unfolded_protein = self.unfolded_protein.get_species(),
                                       Et = self.Et.get_species(), peptide_chain = self.peptide_chain.get_species(),
                                       protease = self.protease.get_species(),
                                        degtag = self.degtag,
                                       cell_count = self.cell_count.get_species())

        # unused mechanism, amino acid replenishment and recycle is added to the translation mechanism
        # aminoacid_pool_maintainence = AminoAcidPool(aminoacid = self.aminoacid.get_species(), 
        #                                peptide_chain = self.peptide_chain.get_species(),
        #                                unfolded_protein = self.unfolded_protein.get_species(),
        #                                cell_count = self.cell_count.get_species(), degtag = self.degtag,
        #                                filter_dict = {"dna":False, "machinery":False, "count":False, "peptide":False,  
        #                                        "degtag":True, "rna":False, "units":False, "X":True, "units0tl":False},
        #                                        default_on = False)
        

        growth_mech = LogisticCellGrowth(cell_count = self.cell_count.get_species())

        # Create Global Dilution and Degradation Mechanisms
        dilution_mechanism = DilutionLogGrowth(cell_count = self.cell_count.get_species(),
                                               filter_dict = {"dna":False, "machinery":False, "count":False, "peptide":True,
                                               "degtag":True, "rna":True, "units":False, "X":True, "units0tl":True},
                                               default_on = False)
        
        mech_rna_deg = BacterialDegradation_mRNA(nuclease = self.rnaase.get_species(),
                                                 nucleotide = self.nucleotide.get_species(),
                                                 cell_count = self.cell_count.get_species(),
                                                 filter_dict = {"rna":True, "machinery":False},
                                                 default_on = False)
        
        # Mechanism unused, deg-tag mechanism is added into the translation mechanism 
        # mech_deg_tag = BacterialDegradationTagged(aminoacid = self.aminoacid.get_species(),
        #                                           peptide_chain = self.peptide_chain.get_species(),
        #                                           protease = self.protease.get_species(),
        #                                           
        #                                            unfolded_protein = self.unfolded_protein.get_species(),
        #                                            cell_count = self.cell_count.get_species(),
        #                                            filter_dict = {"X":True, "machinery":False,
        #                                                           "dna":False, "degtag":True,"rna":False},
        #                                            default_on = False)
        mech_non_tag_deg = BacterialDegradation_active(unfolded_protein = self.unfolded_protein.get_species(),
                                                      aminoacid = self.aminoacid.get_species(),
                                                      peptide_chain = self.peptide_chain.get_species(),
                                                      cell_count = self.cell_count.get_species(),
                                                      filter_dict = {"X":True, "machinery":False,
                                                                  "dna":False, "degtag":True,"rna":False},
                                                      default_on = False)

        default_mechanisms = {
            mech_tx.mechanism_type: mech_tx,
            mech_tl.mechanism_type: mech_tl,
            #aminoacid_pool_maintainence.mechanism_type: aminoacid_pool_maintainence,
            growth_mech.mechanism_type:growth_mech,
            mech_rna_deg.mechanism_type:mech_rna_deg,
            mech_non_tag_deg.mechanism_type: mech_non_tag_deg,
            "dilution":dilution_mechanism,
        }

        
        # if degtag:
        #     default_mechanisms[mech_deg_tag.mechanism_type]=mech_deg_tag
        # The above statement is not needed anymore as the statement is already used in the translation mechanism

        self.add_mechanisms(default_mechanisms)

# %%
G = DNAassembly("X", promoter = "prom_X", rbs = "rbs_X", transcript = "T_X", protein = "X")

# GEAGS parameters files is already loaded with the correct estimated parameters for the CRN model


M_deg = BacterialMixture("E. coli extract", components = [G],
                     parameter_file = "GEAGS_parameters.txt", overwrite_parameters = False, degtag = True)
CRN_deg = M_deg.compile_crn(add_reaction_species = True)
print(repr(M_deg),"\n", CRN_deg.pretty_print(show_attributes = True, show_material = True, show_rates = True),"\n\n")

M_no_deg = BacterialMixture("E. coli extract", components = [G],
                     parameter_file = "GEAGS_parameters.txt", overwrite_parameters = False, degtag = False)
CRN_no_deg = M_no_deg.compile_crn(add_reaction_species = True)

# Prinitng all the CRN reaction rates 

print(repr(M_no_deg),"\n", CRN_no_deg.pretty_print(show_attributes = True, show_material = True, show_rates = True),"\n\n")
# Out:
# BacterialMixture: E. coli extract
# Components = [
# 	DNAassembly: X
# 	Protein: RNAP
# 	Protein: sigma
# 	Protein: Ribo
# 	Protein: RNAase
# 	Protein: NT
# 	Protein: AA
# 	Protein: tRNA
# 	Protein: Et
# 	Protein: unfolded_protein
# 	Protein: peptide_chain
# 	Protein: protease
# 	CellGrowth: cell_count ]
# Mechanisms = {
# 	transcription:bacterial_transcription
# 	translation:bacterial_translation
# 	logistic_cell_growth:logistic_cell_growth }
# Global Mechanisms = {
# 	mrna_degradation:mrna_degradation
# 	non_tag_degradation:non_tag_degradation
# 	dilution:global_dilution_logistic_growth }
#  Species(N = 28) = {
# protein[unfolded_protein(degtag)] (@ 0),  protein[tRNA(machinery)] (@ 0),  protein[sigma(machinery)] (@ 0),  complex[protein[protease]:protein[unfolded_protein]] (@ 0),  complex[protein[X]:protein[protease]] (@ 0),  complex[protein[RNAase]:rna[T_X]] (@ 0),  complex[protein[RNAP]:protein[sigma]] (@ 0),  complex[protein[AA]:protein[tRNA]] (@ 0),  complex[protein[AA]:protein[Et](amp)] (@ 0),  complex[protein[AA]:protein[Et]] (@ 0),  protein[protease(machinery)] (@ 0),  protein[peptide_chain(peptide)] (@ 0),  complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)] (@ 0),  complex[complex[protein[RNAP]:protein[sigma]]:dna[X]] (@ 0),  complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]] (@ 0),  complex[complex[protein[AA]:protein[Et]]:protein[tRNA](active)] (@ 0),  complex[complex[protein[AA]:protein[Et]]:protein[tRNA](inactive)] (@ 0),  complex[complex[protein[AA]:protein[Et]]:protein[tRNA]] (@ 0),  cell_count(count) (@ 0),  protein[X] (@ 0),  dna[X] (@ 0),  rna[T_X] (@ 0),  protein[Ribo(machinery)] (@ 0),  protein[RNAase(machinery)] (@ 0),  protein[RNAP(machinery)] (@ 0),  protein[NT(units)] (@ 0),  protein[Et(machinery)] (@ 0),  protein[AA(units0tl)] (@ 0),
# }
#
# Reactions (34) = [
# 0. protein[sigma(machinery)]+protein[RNAP(machinery)] <--> complex[protein[RNAP]:protein[sigma]]
#  Kf=k_forward * protein_sigma_machinery * protein_RNAP_machinery
#  Kr=k_reverse * complex_protein_RNAP_machinery_protein_sigma_machinery_
#   k_forward=0.0506
#   found_key=(mech=bacterial_transcription, partid=None, name=k_tx_1b).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_tx_1b).
#   k_reverse=13.66
#   found_key=(mech=bacterial_transcription, partid=None, name=k_tx_1u).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_tx_1u).
#
# 1. complex[protein[RNAP]:protein[sigma]]+dna[X] --> complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)]
#  Kf=k_forward * complex_protein_RNAP_machinery_protein_sigma_machinery_ * dna_X
#   k_forward=0.000197944
#   found_key=(mech=bacterial_transcription, partid=None, name=k_tx_2b).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_tx_2b).
#
# 2. complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)] --> complex[protein[RNAP]:protein[sigma]]+dna[X]
#  Kf = k * complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)] *((cell_count(count)/c_max)^n/(1 + (cell_count(count)/c_max)^n))
#   k=0.05461
#   found_key=(mech=bacterial_transcription, partid=None, name=k_tx_2u).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_tx_2u).
#   n=5.5
#   found_key=(mech=None, partid=None, name=n).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=n).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=prom_X, name=c_max).
#
# 3. protein[NT(units)]+complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)] --> dna[X]+protein[RNAP(machinery)]+rna[T_X]+protein[sigma(machinery)]
#  Kf=k_forward * protein_NT_units * complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_
#   k_forward=0.00232
#   found_key=(mech=bacterial_transcription, partid=None, name=k_tx_3).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_tx_3).
#
# 4.  --> protein[RNAP(machinery)]
#  Kf = k * (protein[RNAP(machinery)] + complex[protein[RNAP]:protein[sigma]]  + complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)] - S_min) *(1 - 2*cell_count(count)/c_max)
#   k=0.024963
#   found_key=(mech=bacterial_transcription, partid=None, name=k_rnap).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_rnap).
#   S_min=199.4
#   found_key=(mech=bacterial_transcription, partid=None, name=rnap_min).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=rnap_min).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=prom_X, name=c_max).
#
# 5. protein[AA(units0tl)]+protein[Et(machinery)] <--> complex[protein[AA]:protein[Et]]
#  Kf=k_forward * protein_AA_units0tl * protein_Et_machinery
#  Kr=k_reverse * complex_protein_AA_units0tl_protein_Et_machinery_
#   k_forward=0.453
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_1b).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_1b).
#   k_reverse=69930.0
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_1u).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_1u).
#
# 6. complex[protein[AA]:protein[Et]] --> complex[protein[AA]:protein[Et](amp)]
#  Kf=k_forward * complex_protein_AA_units0tl_protein_Et_machinery_
#   k_forward=39960.0
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_2).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_2).
#
# 7. complex[protein[AA]:protein[Et](amp)]+protein[tRNA(machinery)] --> complex[complex[protein[AA]:protein[Et]]:protein[tRNA](inactive)]
#  Kf=k_forward * complex_protein_AA_units0tl_protein_Et_machinery_amp_ * protein_tRNA_machinery
#   k_forward=9.958
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_3).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_3).
#
# 8. complex[complex[protein[AA]:protein[Et]]:protein[tRNA](inactive)] --> complex[complex[protein[AA]:protein[Et]]:protein[tRNA](active)]
#  Kf=k_forward * complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_
#   k_forward=590.88
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_4).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_4).
#
# 9. complex[complex[protein[AA]:protein[Et]]:protein[tRNA](active)] --> complex[protein[AA]:protein[tRNA]]+protein[Et(machinery)]
#  Kf=k_forward * complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_
#   k_forward=138.88
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_5).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_5).
#
# 10. complex[protein[AA]:protein[tRNA]]+protein[Ribo(machinery)]+rna[T_X] <--> complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]]
#  Kf=k_forward * complex_protein_AA_units0tl_protein_tRNA_machinery_ * protein_Ribo_machinery * rna_T_X
#  Kr=k_reverse * complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_
#   k_forward=0.00197
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_6b).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_6b).
#   k_reverse=742.71
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_6u).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_6u).
#
# 11. complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]] --> rna[T_X]+protein[Ribo(machinery)]+protein[unfolded_protein(degtag)]+protein[tRNA(machinery)]
#  Kf = k * complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]] *(1 - cell_count(count)/c_max + b)
#   k=3.765
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_7).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_7).
#   b=1.17
#   found_key=(mech=bacterial_translation, partid=None, name=b_tl_7).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=b_tl_7).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 12. protein[unfolded_protein(degtag)] --> protein[X]
#  Kf = k * protein[unfolded_protein(degtag)] *((cell_count(count)/C_max) * (1 - cell_count(count)/C_max) * (1 - (protein[unfolded_protein(degtag)]+protein[X])/P_max) + b)
#   k=0.1
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_8).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_8).
#   P_max=31104.0
#   found_key=(mech=bacterial_translation, partid=None, name=P_max).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=P_max).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#   b=0.5
#   found_key=(mech=bacterial_translation, partid=None, name=b_tl_8).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=b_tl_8).
#
# 13.  --> protein[tRNA(machinery)]
#  Kf = k * (protein[tRNA(machinery)] + complex[complex[protein[AA]:protein[Et]]:protein[tRNA](inactive)]  + complex[complex[protein[AA]:protein[Et]]:protein[tRNA](active)] + complex[protein[AA]:protein[tRNA]] + complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]] - S_min) *(1 - 2*cell_count(count)/c_max)
#   k=0.0109
#   found_key=(mech=bacterial_translation, partid=None, name=k_tRNA).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tRNA).
#   S_min=106.41
#   found_key=(mech=bacterial_translation, partid=None, name=tRNA_min).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=tRNA_min).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 14.  --> protein[Ribo(machinery)]
#  Kf = k * (protein[Ribo(machinery)] + complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]] - S_min) *(1 - 2*cell_count(count)/c_max)
#   k=0.0055
#   found_key=(mech=bacterial_translation, partid=None, name=k_ribo).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_ribo).
#   S_min=173.15
#   found_key=(mech=bacterial_translation, partid=None, name=ribo_min).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=ribo_min).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 15.  --> protein[Et(machinery)]
#  Kf = k * (protein[Et(machinery)] + complex[protein[AA]:protein[Et]]  + complex[protein[AA]:protein[Et](amp)] + complex[complex[protein[AA]:protein[Et]]:protein[tRNA](inactive)] + complex[complex[protein[AA]:protein[Et]]:protein[tRNA](active)] - S_min) *(1 - 2*cell_count(count)/c_max)
#   k=0.02099
#   found_key=(mech=bacterial_translation, partid=None, name=k_Et).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_Et).
#   S_min=160.8
#   found_key=(mech=bacterial_translation, partid=None, name=Et_min).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=Et_min).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 16. protein[peptide_chain(peptide)] --> protein[AA(units0tl)]
#  Kf=k_forward * protein_peptide_chain_peptide
#   k_forward=0.0005
#   found_key=(mech=None, partid=None, name=k_tl_11).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_11).
#
# 17.  --> protein[AA(units0tl)]
#  Kf = k *(1 - cell_count(count)/c_max ) * (cell_count(count)/c_max)
#   k=515.476
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_12).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_12).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 18.  --> protein[protease(machinery)]
#  Kf = k * (protein[protease(machinery)] + complex[protein[protease]:protein[unfolded_protein]]  + complex[protein[X]:protein[protease]] - S_min) *(1 - 2*cell_count(count)/c_max)
#   k=0.01603749
#   found_key=(mech=bacterial_translation, partid=None, name=k_protease).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_protease).
#   S_min=175.9651
#   found_key=(mech=bacterial_translation, partid=None, name=protease_min).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=protease_min).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 19. protein[unfolded_protein(degtag)]+protein[protease(machinery)] <--> complex[protein[protease]:protein[unfolded_protein]]
#  Kf=k_forward * protein_unfolded_protein_degtag * protein_protease_machinery
#  Kr=k_reverse * complex_protein_protease_machinery_protein_unfolded_protein_degtag_
#   k_forward=6.6885
#   found_key=(mech=None, partid=None, name=k_tl_13b).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_13b).
#   k_reverse=2544.593
#   found_key=(mech=None, partid=None, name=k_tl_13u).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_13u).
#
# 20. complex[protein[protease]:protein[unfolded_protein]] --> protein[peptide_chain(peptide)]+protein[protease(machinery)]
#  Kf=k_forward * complex_protein_protease_machinery_protein_unfolded_protein_degtag_
#   k_forward=0.1007
#   found_key=(mech=None, partid=None, name=k_tl_9).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_9).
#
# 21. protein[X]+protein[protease(machinery)] <--> complex[protein[X]:protein[protease]]
#  Kf=k_forward * protein_X * protein_protease_machinery
#  Kr=k_reverse * complex_protein_X_protein_protease_machinery_
#   k_forward=6.6885
#   found_key=(mech=None, partid=None, name=k_tl_13b).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_13b).
#   k_reverse=2544.593
#   found_key=(mech=None, partid=None, name=k_tl_13u).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_13u).
#
# 22. complex[protein[X]:protein[protease]] --> protein[peptide_chain(peptide)]+protein[protease(machinery)]
#  Kf=k_forward * complex_protein_X_protein_protease_machinery_
#   k_forward=0.1007
#   found_key=(mech=None, partid=None, name=k_tl_9).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_9).
#
# 23.  --> cell_count(count)
#  Kf = k cell_count(count)* ( 1 - cell_count(count)/c_max)
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=cell_count, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=cell_count, name=c_max).
#
# 24. rna[T_X]+protein[RNAase(machinery)] --> complex[protein[RNAase]:rna[T_X]]
#  Kf=k_forward * rna_T_X * protein_RNAase_machinery
#   k_forward=2.5497
#   found_key=(mech=None, partid=None, name=k_tx_4b).
#   search_key=(mech=mrna_degradation, partid=rna_T_X, name=k_tx_4b).
#
# 25. complex[protein[RNAase]:rna[T_X]] --> rna[T_X]+protein[RNAase(machinery)]
#  Kf = k * complex[protein[RNAase]:rna[T_X]] *((cell_count(count)/c_max)^n/(1 + (cell_count(count)/c_max)^n) + b)
#   k=181.72
#   found_key=(mech=None, partid=None, name=k_tx_4u).
#   search_key=(mech=mrna_degradation, partid=rna_T_X, name=k_tx_4u).
#   b=1.0
#   found_key=(mech=mrna_degradation, partid=None, name=b_tx_4u).
#   search_key=(mech=mrna_degradation, partid=rna_T_X, name=b_tx_4u).
#   n=5.5
#   found_key=(mech=mrna_degradation, partid=None, name=n).
#   search_key=(mech=mrna_degradation, partid=rna_T_X, name=n).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 26. complex[protein[RNAase]:rna[T_X]] --> protein[RNAase(machinery)]+protein[NT(units)]
#  Kf=k_forward * complex_protein_RNAase_machinery_rna_T_X_
#   k_forward=1.881
#   found_key=(mech=None, partid=None, name=k_tx_5).
#   search_key=(mech=mrna_degradation, partid=rna_T_X, name=k_tx_5).
#
# 27. protein[X] --> protein[peptide_chain(peptide)]
#  Kf = k * protein[X] *((cell_count(count)/c_max)^n/(1 + (cell_count(count)/c_max)^n))
#   k=0.001
#   found_key=(mech=None, partid=None, name=k_tl_10).
#   search_key=(mech=non_tag_degradation, partid=protein_X, name=k_tl_10).
#   n=5.5
#   found_key=(mech=None, partid=None, name=n).
#   search_key=(mech=non_tag_degradation, partid=protein_X, name=n).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 28. protein[unfolded_protein(degtag)] --> protein[peptide_chain(peptide)]
#  Kf = k * protein[unfolded_protein(degtag)] *((cell_count(count)/c_max)^n/(1 + (cell_count(count)/c_max)^n))
#   k=0.001
#   found_key=(mech=None, partid=None, name=k_tl_10).
#   search_key=(mech=non_tag_degradation, partid=protein_unfolded_protein_degtag, name=k_tl_10).
#   n=5.5
#   found_key=(mech=None, partid=None, name=n).
#   search_key=(mech=non_tag_degradation, partid=protein_unfolded_protein_degtag, name=n).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 29. rna[T_X] -->
#  Kf = k * rna[T_X] *(1 - cell_count(count)/c_max )
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=None, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 30. protein[AA(units0tl)] -->
#  Kf = k * protein[AA(units0tl)] *(1 - cell_count(count)/c_max )
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=None, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 31. protein[X] -->
#  Kf = k * protein[X] *(1 - cell_count(count)/c_max )
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=None, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 32. protein[unfolded_protein(degtag)] -->
#  Kf = k * protein[unfolded_protein(degtag)] *(1 - cell_count(count)/c_max )
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=None, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 33. protein[peptide_chain(peptide)] -->
#  Kf = k * protein[peptide_chain(peptide)] *(1 - cell_count(count)/c_max )
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=None, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# ]
#
#
# BacterialMixture: E. coli extract
# Components = [
# 	DNAassembly: X
# 	Protein: RNAP
# 	Protein: sigma
# 	Protein: Ribo
# 	Protein: RNAase
# 	Protein: NT
# 	Protein: AA
# 	Protein: tRNA
# 	Protein: Et
# 	Protein: unfolded_protein
# 	Protein: peptide_chain
# 	Protein: protease
# 	CellGrowth: cell_count ]
# Mechanisms = {
# 	transcription:bacterial_transcription
# 	translation:bacterial_translation
# 	logistic_cell_growth:logistic_cell_growth }
# Global Mechanisms = {
# 	mrna_degradation:mrna_degradation
# 	non_tag_degradation:non_tag_degradation
# 	dilution:global_dilution_logistic_growth }
#  Species(N = 28) = {
# protein[unfolded_protein(degtag)] (@ 0),  protein[tRNA(machinery)] (@ 0),  protein[sigma(machinery)] (@ 0),  complex[protein[protease]:protein[unfolded_protein]] (@ 0),  complex[protein[X]:protein[protease]] (@ 0),  complex[protein[RNAase]:rna[T_X]] (@ 0),  complex[protein[RNAP]:protein[sigma]] (@ 0),  complex[protein[AA]:protein[tRNA]] (@ 0),  complex[protein[AA]:protein[Et](amp)] (@ 0),  complex[protein[AA]:protein[Et]] (@ 0),  protein[protease(machinery)] (@ 0),  protein[peptide_chain(peptide)] (@ 0),  complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)] (@ 0),  complex[complex[protein[RNAP]:protein[sigma]]:dna[X]] (@ 0),  complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]] (@ 0),  complex[complex[protein[AA]:protein[Et]]:protein[tRNA](active)] (@ 0),  complex[complex[protein[AA]:protein[Et]]:protein[tRNA](inactive)] (@ 0),  complex[complex[protein[AA]:protein[Et]]:protein[tRNA]] (@ 0),  cell_count(count) (@ 0),  protein[X] (@ 0),  dna[X] (@ 0),  rna[T_X] (@ 0),  protein[Ribo(machinery)] (@ 0),  protein[RNAase(machinery)] (@ 0),  protein[RNAP(machinery)] (@ 0),  protein[NT(units)] (@ 0),  protein[Et(machinery)] (@ 0),  protein[AA(units0tl)] (@ 0),
# }
#
# Reactions (30) = [
# 0. protein[sigma(machinery)]+protein[RNAP(machinery)] <--> complex[protein[RNAP]:protein[sigma]]
#  Kf=k_forward * protein_sigma_machinery * protein_RNAP_machinery
#  Kr=k_reverse * complex_protein_RNAP_machinery_protein_sigma_machinery_
#   k_forward=0.0506
#   found_key=(mech=bacterial_transcription, partid=None, name=k_tx_1b).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_tx_1b).
#   k_reverse=13.66
#   found_key=(mech=bacterial_transcription, partid=None, name=k_tx_1u).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_tx_1u).
#
# 1. complex[protein[RNAP]:protein[sigma]]+dna[X] --> complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)]
#  Kf=k_forward * complex_protein_RNAP_machinery_protein_sigma_machinery_ * dna_X
#   k_forward=0.000197944
#   found_key=(mech=bacterial_transcription, partid=None, name=k_tx_2b).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_tx_2b).
#
# 2. complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)] --> complex[protein[RNAP]:protein[sigma]]+dna[X]
#  Kf = k * complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)] *((cell_count(count)/c_max)^n/(1 + (cell_count(count)/c_max)^n))
#   k=0.05461
#   found_key=(mech=bacterial_transcription, partid=None, name=k_tx_2u).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_tx_2u).
#   n=5.5
#   found_key=(mech=None, partid=None, name=n).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=n).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=prom_X, name=c_max).
#
# 3. protein[NT(units)]+complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)] --> dna[X]+protein[RNAP(machinery)]+rna[T_X]+protein[sigma(machinery)]
#  Kf=k_forward * protein_NT_units * complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_
#   k_forward=0.00232
#   found_key=(mech=bacterial_transcription, partid=None, name=k_tx_3).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_tx_3).
#
# 4.  --> protein[RNAP(machinery)]
#  Kf = k * (protein[RNAP(machinery)] + complex[protein[RNAP]:protein[sigma]]  + complex[complex[protein[RNAP]:protein[sigma]]:dna[X](open)] - S_min) *(1 - 2*cell_count(count)/c_max)
#   k=0.024963
#   found_key=(mech=bacterial_transcription, partid=None, name=k_rnap).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=k_rnap).
#   S_min=199.4
#   found_key=(mech=bacterial_transcription, partid=None, name=rnap_min).
#   search_key=(mech=bacterial_transcription, partid=prom_X, name=rnap_min).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=prom_X, name=c_max).
#
# 5. protein[AA(units0tl)]+protein[Et(machinery)] <--> complex[protein[AA]:protein[Et]]
#  Kf=k_forward * protein_AA_units0tl * protein_Et_machinery
#  Kr=k_reverse * complex_protein_AA_units0tl_protein_Et_machinery_
#   k_forward=0.453
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_1b).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_1b).
#   k_reverse=69930.0
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_1u).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_1u).
#
# 6. complex[protein[AA]:protein[Et]] --> complex[protein[AA]:protein[Et](amp)]
#  Kf=k_forward * complex_protein_AA_units0tl_protein_Et_machinery_
#   k_forward=39960.0
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_2).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_2).
#
# 7. complex[protein[AA]:protein[Et](amp)]+protein[tRNA(machinery)] --> complex[complex[protein[AA]:protein[Et]]:protein[tRNA](inactive)]
#  Kf=k_forward * complex_protein_AA_units0tl_protein_Et_machinery_amp_ * protein_tRNA_machinery
#   k_forward=9.958
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_3).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_3).
#
# 8. complex[complex[protein[AA]:protein[Et]]:protein[tRNA](inactive)] --> complex[complex[protein[AA]:protein[Et]]:protein[tRNA](active)]
#  Kf=k_forward * complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_
#   k_forward=590.88
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_4).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_4).
#
# 9. complex[complex[protein[AA]:protein[Et]]:protein[tRNA](active)] --> complex[protein[AA]:protein[tRNA]]+protein[Et(machinery)]
#  Kf=k_forward * complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_
#   k_forward=138.88
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_5).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_5).
#
# 10. complex[protein[AA]:protein[tRNA]]+protein[Ribo(machinery)]+rna[T_X] <--> complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]]
#  Kf=k_forward * complex_protein_AA_units0tl_protein_tRNA_machinery_ * protein_Ribo_machinery * rna_T_X
#  Kr=k_reverse * complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_
#   k_forward=0.00197
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_6b).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_6b).
#   k_reverse=742.71
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_6u).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_6u).
#
# 11. complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]] --> rna[T_X]+protein[Ribo(machinery)]+protein[unfolded_protein(degtag)]+protein[tRNA(machinery)]
#  Kf = k * complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]] *(1 - cell_count(count)/c_max + b)
#   k=3.765
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_7).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_7).
#   b=1.17
#   found_key=(mech=bacterial_translation, partid=None, name=b_tl_7).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=b_tl_7).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 12. protein[unfolded_protein(degtag)] --> protein[X]
#  Kf = k * protein[unfolded_protein(degtag)] *((cell_count(count)/C_max) * (1 - cell_count(count)/C_max) * (1 - (protein[unfolded_protein(degtag)]+protein[X])/P_max) + b)
#   k=0.1
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_8).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_8).
#   P_max=31104.0
#   found_key=(mech=bacterial_translation, partid=None, name=P_max).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=P_max).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#   b=0.5
#   found_key=(mech=bacterial_translation, partid=None, name=b_tl_8).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=b_tl_8).
#
# 13.  --> protein[tRNA(machinery)]
#  Kf = k * (protein[tRNA(machinery)] + complex[complex[protein[AA]:protein[Et]]:protein[tRNA](inactive)]  + complex[complex[protein[AA]:protein[Et]]:protein[tRNA](active)] + complex[protein[AA]:protein[tRNA]] + complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]] - S_min) *(1 - 2*cell_count(count)/c_max)
#   k=0.0109
#   found_key=(mech=bacterial_translation, partid=None, name=k_tRNA).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tRNA).
#   S_min=106.41
#   found_key=(mech=bacterial_translation, partid=None, name=tRNA_min).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=tRNA_min).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 14.  --> protein[Ribo(machinery)]
#  Kf = k * (protein[Ribo(machinery)] + complex[complex[protein[AA]:protein[tRNA]]:protein[Ribo]:rna[T_X]] - S_min) *(1 - 2*cell_count(count)/c_max)
#   k=0.0055
#   found_key=(mech=bacterial_translation, partid=None, name=k_ribo).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_ribo).
#   S_min=173.15
#   found_key=(mech=bacterial_translation, partid=None, name=ribo_min).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=ribo_min).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 15.  --> protein[Et(machinery)]
#  Kf = k * (protein[Et(machinery)] + complex[protein[AA]:protein[Et]]  + complex[protein[AA]:protein[Et](amp)] + complex[complex[protein[AA]:protein[Et]]:protein[tRNA](inactive)] + complex[complex[protein[AA]:protein[Et]]:protein[tRNA](active)] - S_min) *(1 - 2*cell_count(count)/c_max)
#   k=0.02099
#   found_key=(mech=bacterial_translation, partid=None, name=k_Et).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_Et).
#   S_min=160.8
#   found_key=(mech=bacterial_translation, partid=None, name=Et_min).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=Et_min).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 16. protein[peptide_chain(peptide)] --> protein[AA(units0tl)]
#  Kf=k_forward * protein_peptide_chain_peptide
#   k_forward=0.0005
#   found_key=(mech=None, partid=None, name=k_tl_11).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_11).
#
# 17.  --> protein[AA(units0tl)]
#  Kf = k *(1 - cell_count(count)/c_max ) * (cell_count(count)/c_max)
#   k=515.476
#   found_key=(mech=bacterial_translation, partid=None, name=k_tl_12).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_tl_12).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 18.  --> protein[protease(machinery)]
#  Kf = k * (protein[protease(machinery)] + complex[protein[protease]:protein[unfolded_protein]]  + complex[protein[X]:protein[protease]] - S_min) *(1 - 2*cell_count(count)/c_max)
#   k=0.01603749
#   found_key=(mech=bacterial_translation, partid=None, name=k_protease).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=k_protease).
#   S_min=175.9651
#   found_key=(mech=bacterial_translation, partid=None, name=protease_min).
#   search_key=(mech=bacterial_translation, partid=rbs_X, name=protease_min).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=rbs_X, name=c_max).
#
# 19.  --> cell_count(count)
#  Kf = k cell_count(count)* ( 1 - cell_count(count)/c_max)
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=cell_count, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=cell_count, name=c_max).
#
# 20. rna[T_X]+protein[RNAase(machinery)] --> complex[protein[RNAase]:rna[T_X]]
#  Kf=k_forward * rna_T_X * protein_RNAase_machinery
#   k_forward=2.5497
#   found_key=(mech=None, partid=None, name=k_tx_4b).
#   search_key=(mech=mrna_degradation, partid=rna_T_X, name=k_tx_4b).
#
# 21. complex[protein[RNAase]:rna[T_X]] --> rna[T_X]+protein[RNAase(machinery)]
#  Kf = k * complex[protein[RNAase]:rna[T_X]] *((cell_count(count)/c_max)^n/(1 + (cell_count(count)/c_max)^n) + b)
#   k=181.72
#   found_key=(mech=None, partid=None, name=k_tx_4u).
#   search_key=(mech=mrna_degradation, partid=rna_T_X, name=k_tx_4u).
#   b=1.0
#   found_key=(mech=mrna_degradation, partid=None, name=b_tx_4u).
#   search_key=(mech=mrna_degradation, partid=rna_T_X, name=b_tx_4u).
#   n=5.5
#   found_key=(mech=mrna_degradation, partid=None, name=n).
#   search_key=(mech=mrna_degradation, partid=rna_T_X, name=n).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 22. complex[protein[RNAase]:rna[T_X]] --> protein[RNAase(machinery)]+protein[NT(units)]
#  Kf=k_forward * complex_protein_RNAase_machinery_rna_T_X_
#   k_forward=1.881
#   found_key=(mech=None, partid=None, name=k_tx_5).
#   search_key=(mech=mrna_degradation, partid=rna_T_X, name=k_tx_5).
#
# 23. protein[X] --> protein[peptide_chain(peptide)]
#  Kf = k * protein[X] *((cell_count(count)/c_max)^n/(1 + (cell_count(count)/c_max)^n))
#   k=0.001
#   found_key=(mech=None, partid=None, name=k_tl_10).
#   search_key=(mech=non_tag_degradation, partid=protein_X, name=k_tl_10).
#   n=5.5
#   found_key=(mech=None, partid=None, name=n).
#   search_key=(mech=non_tag_degradation, partid=protein_X, name=n).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 24. protein[unfolded_protein(degtag)] --> protein[peptide_chain(peptide)]
#  Kf = k * protein[unfolded_protein(degtag)] *((cell_count(count)/c_max)^n/(1 + (cell_count(count)/c_max)^n))
#   k=0.001
#   found_key=(mech=None, partid=None, name=k_tl_10).
#   search_key=(mech=non_tag_degradation, partid=protein_unfolded_protein_degtag, name=k_tl_10).
#   n=5.5
#   found_key=(mech=None, partid=None, name=n).
#   search_key=(mech=non_tag_degradation, partid=protein_unfolded_protein_degtag, name=n).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 25. rna[T_X] -->
#  Kf = k * rna[T_X] *(1 - cell_count(count)/c_max )
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=None, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 26. protein[AA(units0tl)] -->
#  Kf = k * protein[AA(units0tl)] *(1 - cell_count(count)/c_max )
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=None, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 27. protein[X] -->
#  Kf = k * protein[X] *(1 - cell_count(count)/c_max )
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=None, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 28. protein[unfolded_protein(degtag)] -->
#  Kf = k * protein[unfolded_protein(degtag)] *(1 - cell_count(count)/c_max )
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=None, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# 29. protein[peptide_chain(peptide)] -->
#  Kf = k * protein[peptide_chain(peptide)] *(1 - cell_count(count)/c_max )
#   k=0.015781
#   found_key=(mech=logistic_cell_growth, partid=None, name=k).
#   search_key=(mech=logistic_cell_growth, partid=None, name=k).
#   c_max=503666666.6666667
#   found_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#   search_key=(mech=logistic_cell_growth, partid=None, name=c_max).
#
# ]
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_ has multiple attributes(or material type) which conflict with global mechanism filter mrna_degradation. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species dna_X has multiple attributes(or material type) which conflict with global mechanism filter non_tag_degradation. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species dna_X has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_protein_AA_units0tl_protein_Et_machinery_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_AA_units0tl_protein_Et_machinery__protein_tRNA_machinery_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_protein_AA_units0tl_protein_tRNA_machinery_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_protein_protease_machinery_protein_unfolded_protein_degtag_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_protein_X_protein_protease_machinery_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_protein_AA_units0tl_protein_Et_machinery_amp_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_ has multiple attributes(or material type) which conflict with global mechanism filter mrna_degradation. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species dna_X has multiple attributes(or material type) which conflict with global mechanism filter non_tag_degradation. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species dna_X has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_protein_AA_units0tl_protein_Et_machinery_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_AA_units0tl_protein_Et_machinery__protein_tRNA_machinery_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_protein_AA_units0tl_protein_tRNA_machinery_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_protein_protease_machinery_protein_unfolded_protein_degtag_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_protein_X_protein_protease_machinery_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_protein_AA_units0tl_protein_Et_machinery_amp_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/global_mechanism.py:104: UserWarning: species complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_ has multiple attributes(or material type) which conflict with global mechanism filter global_dilution_logistic_growth. Using default value False.
#   warn(f"species {repr(s)} has multiple attributes(or material type) which conflict with global mechanism filter {repr(self)}. Using default value {self.default_on}.")

# %% [markdown]
# ### Write CRN to an SBML file and then simulate using Bioscrape

# %%
CRN_deg.write_sbml_file('GEAGS_biocrnpyler_degtag_062124_4.xml')

CRN_no_deg.write_sbml_file('GEAGS_biocrnpyler_no_degtag_062124_4.xml')
# Out:
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/units.py:134: UserWarning: The string identifier for the unit unit is not supported by BioCRNpyler. Add this to the dictionary in biocrnpyler/units.py if you want this unit.
#   warnings.warn('The string identifier for the unit {0} is not supported by BioCRNpyler. Add this to the dictionary in biocrnpyler/units.py if you want this unit.'.format(unit_id))
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/units.py:134: UserWarning: The string identifier for the unit dimensionless is not supported by BioCRNpyler. Add this to the dictionary in biocrnpyler/units.py if you want this unit.
#   warnings.warn('The string identifier for the unit {0} is not supported by BioCRNpyler. Add this to the dictionary in biocrnpyler/units.py if you want this unit.'.format(unit_id))
# /opt/conda/envs/py38/lib/python3.8/site-packages/biocrnpyler/units.py:134: UserWarning: The string identifier for the unit add comment here is not supported by BioCRNpyler. Add this to the dictionary in biocrnpyler/units.py if you want this unit.
#   warnings.warn('The string identifier for the unit {0} is not supported by BioCRNpyler. Add this to the dictionary in biocrnpyler/units.py if you want this unit.'.format(unit_id))
# True

# %%
m_deg = Model(sbml_filename = 'GEAGS_biocrnpyler_degtag_062124_4.xml')
m_no_deg = Model(sbml_filename = 'GEAGS_biocrnpyler_no_degtag_062124_4.xml')
t = 1050*1
timepoints = np.linspace(0,t,t*20)

# %%
# Deifning the initial conditions for the CRN which were hand fitted 

m_deg.set_species({'dna_X': 100,
 'protein_RNAP_machinery': 200.69,
 'protein_sigma_machinery': 977.63,
 'protein_NT_units': 962.85,
 'protein_Ribo_machinery': 794.8,
 'protein_AA_units0tl': 50000,
 'protein_tRNA_machinery': 580.4,
 'protein_RNAase_machinery': 72,
 'protein_Et_machinery': 563,
 'protein_protease_machinery': 252,
 'protein_unfolded_protein_degtag': 0,
 'rna_T_X':0,
 'protein_X':0,
 'cell_count_count': 6666666.67})

# m_no_deg.set_params({'r_dil__':1,
#               'k_Et__bacterial_translation':0})

m_no_deg.set_species({'dna_X': 100,
 'protein_RNAP_machinery': 200.69,
 'protein_sigma_machinery': 977.63,
 'protein_NT_units': 962.85,
 'protein_Ribo_machinery': 794.8,
 'protein_AA_units0tl': 50000,
 'protein_tRNA_machinery': 580.4,
 'protein_RNAase_machinery': 72,
 'protein_Et_machinery': 563,
 'protein_protease_machinery': 252,
 'protein_unfolded_protein_degtag': 0,
 'rna_T_X':0,
 'protein_X':0,
 'cell_count_count': 6666666.67})

# m_deg.set_params({'r_dil__':1,
#               'k_Et__bacterial_translation':0})

sol_deg = py_simulate_model(timepoints = timepoints, Model = m_deg)
sol_no_deg = py_simulate_model(timepoints = timepoints, Model = m_no_deg)
# Out:
# /opt/conda/envs/py38/lib/python3.8/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /opt/conda/envs/py38/lib/python3.8/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %% [markdown]
# ## Plotting the results:

# %%
fig, ax = plt.subplots(2,2, figsize = (15,8))
fig.subplots_adjust(wspace = 0.4)#, hspace = 0.1)

r,c = 0,0
ax[r,c].plot(timepoints, sol_deg['protein_X'], label = "GEAGS Model", color = 'royalblue')
ax[r,c].set_xlabel('Time (min)', fontsize = 15) ; ax[r,c].set_ylabel('Folded Protein (nM)', fontsize = 15) 
ax[r,c].set_title('With Deg-tag', fontsize = 15) ; ax[r,c].grid(True) ; ax[r,c].legend()

r,c = 0,1
ax[r,c].plot(timepoints, sol_no_deg['protein_X'], label = "GEAGS Model", color = 'lightcoral')
ax[r,c].set_xlabel('Time (min)', fontsize = 15) ; ax[r,c].set_ylabel('Folded Protein (nM)', fontsize = 15) 
ax[r,c].set_title('Without Deg-tag', fontsize = 15) ; ax[r,c].grid(True) ; ax[r,c].legend()

r,c = 1,0
ax[r,c].scatter(time_A[0], A_non_leaky[0], color = 'royalblue', label = 'Exp. Data')
ax[r,c].scatter(time_A[1], A_non_leaky[1], color = 'royalblue', label = 'Exp. Data')
ax[r,c].scatter(time_A[2], A_non_leaky[2], color = 'royalblue', label = 'Exp. Data')
ax[r,c].set_xlabel('Time (min)', fontsize = 15) ; ax[r,c].set_ylabel('FL/OD', fontsize = 15) ; ax[r,c].legend()
#ax[r,c].set_title('With Deg-tag') ; 
ax[r,c].grid(True)

r,c = 1,1
ax[r,c].scatter(time_B[0], B_non_leaky[0], color = 'lightcoral', label = 'Exp. Data')
ax[r,c].scatter(time_B[1], B_non_leaky[1], color = 'lightcoral', label = 'Exp. Data')
ax[r,c].scatter(time_B[2], B_non_leaky[2], color = 'lightcoral', label = 'Exp. Data')
ax[r,c].set_xlabel('Time (min)', fontsize = 15) ; ax[r,c].set_ylabel('FL/OD', fontsize = 15) ; ax[r,c].legend()
#ax[r,c].set_title('Without Deg-tag') ; 
ax[r,c].grid(True)

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
#fig, ax = plt.subplots(2,1, figsize = (8,12))

ax[0].plot(timepoints, sol_deg['protein_X']/np.max(sol_deg['protein_X']), '--', label = "Model Fit", color = 'black')
ax[0].scatter(time_A[0], A_non_leaky[0]/np.max(A_non_leaky[2]), color = 'royalblue', label = 'Exp. Data')
ax[0].scatter(time_A[1], A_non_leaky[1]/np.max(A_non_leaky[2]), color = 'royalblue', label = 'Exp. Data')
ax[0].scatter(time_A[2], A_non_leaky[2]/np.max(A_non_leaky[2]), color = 'royalblue', label = 'Exp. Data')
ax[0].set_xlabel('Time (min)'); ax[0].grid(True) ; ax[0].legend()

ax[1].plot(timepoints, sol_no_deg['protein_X']/np.max(sol_deg['protein_X']), '--', label = "Model Prediction", color = 'black')
ax[1].scatter(time_B[0], B_non_leaky[0]/np.max(A_non_leaky[2]), color = 'lightcoral', label = 'Exp. Data')
ax[1].scatter(time_B[1], B_non_leaky[1]/np.max(A_non_leaky[2]), color = 'lightcoral', label = 'Exp. Data')
ax[1].scatter(time_B[2], B_non_leaky[2]/np.max(A_non_leaky[2]), color = 'lightcoral', label = 'Exp. Data')
ax[1].set_xlabel('Time (min)'); ax[1].grid(True) ; ax[1].legend()

#fig.savefig("GEAGS_qualitative_comparison.png")

# %% [markdown]
# ### With deg tag

# %%
# Total rnap, bound and unbound
RNAP_total = sol_deg['protein_RNAP_machinery'] + sol_deg['complex_protein_RNAP_machinery_protein_sigma_machinery_']  
RNAP_total += sol_deg['complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_'] 



# Total DNA, bound and unbound
DNA_total = sol_deg['dna_X'] + sol_deg['complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_']

# Total sigma, bound and unbound
sigma_total = sol_deg['protein_sigma_machinery'] + sol_deg['complex_protein_RNAP_machinery_protein_sigma_machinery_'] 
sigma_total += sol_deg['complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_'] 

# Total RNAase, bound and unbound
rnaase_total = sol_deg['protein_RNAase_machinery'] + sol_deg['complex_protein_RNAase_machinery_rna_T_X_']

fig,ax = plt.subplots(nrows = 3, ncols = 3, figsize = (15,10))
ax[0][0].plot(timepoints, sol_deg['cell_count_count'], label = "Cell count")
ax[0][1].plot(timepoints, rnaase_total, label = "Total RNAase");ax[0][1].set_ylim(bottom = 0, top = 75)
ax[0][2].plot(timepoints, sol_deg['protein_NT_units'], label = "Nucleotide")
ax[1][0].plot(timepoints, RNAP_total, label = "Total RNAP")
ax[1][1].plot(timepoints, DNA_total, label = "Total DNA");ax[1][1].set_ylim(bottom = 0, top = 150)
ax[1][2].plot(timepoints, sol_deg['rna_T_X'], label = "mRNA")
ax[2][0].plot(timepoints, sigma_total, label = "Total Sigma"); #ax[2][0].set_ylim(bottom = 0, top = 1500)


ax[0][0].legend() ; ax[0][0].grid(); 
ax[0][1].legend() ; ax[0][1].grid(); 
ax[0][2].legend() ; ax[0][2].grid(); 
ax[2][0].legend() ; ax[1][0].grid(); 
ax[1][0].legend() ; ax[1][1].grid(); 
ax[1][1].legend() ; ax[1][2].grid(); 
ax[1][2].legend() ; ax[2][0].grid(); 
ax[2][1].legend() ; ax[2][1].grid(); 
ax[2][2].legend() ; ax[2][2].grid();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (12,4))

ax[0].plot(timepoints, sol_deg['complex_protein_RNAP_machinery_protein_sigma_machinery_'], label = 'Holoenzyme')
ax[1].plot(timepoints, sol_deg['complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_'] , label = 'Open Complex')
ax[0].legend(); ax[1].legend(); 
ax[0].grid(); ax[1].grid();

# %%
# Total Ribosome, bound and unbound
ribo_total = sol_deg['protein_Ribo_machinery'] 
ribo_total += sol_deg['complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_']

# Total tRNA, bound and unbound
tRNA_total = sol_deg['protein_tRNA_machinery'] + sol_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_']
tRNA_total += sol_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_']
tRNA_total += sol_deg['complex_protein_AA_units0tl_protein_tRNA_machinery_']
tRNA_total += sol_deg['complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_']

# Total mRNA, bound and unbound
mrna_total = sol_deg['rna_T_X'] 
mrna_total += sol_deg['complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_']
mrna_total += sol_deg['complex_protein_RNAase_machinery_rna_T_X_']


# Total tRNA synthetase
synth_total = sol_deg['protein_Et_machinery']
synth_total += sol_deg['complex_protein_AA_units0tl_protein_Et_machinery_']
synth_total += sol_deg['complex_protein_AA_units0tl_protein_Et_machinery_amp_']
synth_total += sol_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_']
synth_total += sol_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_']


# Total Amino Acid 
aa_total = sol_deg['protein_AA_units0tl'] 
aa_total += sol_deg['complex_protein_AA_units0tl_protein_Et_machinery_']
aa_total += sol_deg['complex_protein_AA_units0tl_protein_Et_machinery_amp_']
aa_total += sol_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_']
aa_total += sol_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_']
aa_total += sol_deg['complex_protein_AA_units0tl_protein_tRNA_machinery_']
aa_total += sol_deg['complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_']

fig,ax = plt.subplots(nrows = 3, ncols = 3, figsize = (15,10))
# ax.set_title("Growth dependent gene expression")

ax[0][0].plot(timepoints, sol_deg['cell_count_count'], label = "Cell count")
ax[0][1].plot(timepoints, ribo_total, label = "Total Ribosome")
ax[0][2].plot(timepoints, sol_deg['protein_AA_units0tl'] , label = "Amino Acid")
ax[1][0].plot(timepoints, synth_total, label = "tRNA-Synthetase")
ax[1][1].plot(timepoints, tRNA_total, label = "Total tRNA")
ax[1][2].plot(timepoints, sol_deg['protein_X'], label = "Protein")
ax[2][0].plot(timepoints, sol_deg['protein_unfolded_protein_degtag'], label = "Unfolded Protein")
ax[2][1].plot(timepoints, mrna_total, label = "Total mRNA")
ax[2][2].plot(timepoints, sol_deg['protein_peptide_chain_peptide'], label = "Peptide")


ax[0][0].legend() ; ax[0][0].grid(); 
ax[0][1].legend() ; ax[0][1].grid(); 
ax[0][2].legend() ; ax[0][2].grid(); 
ax[2][0].legend() ; ax[1][0].grid(); 
ax[1][0].legend() ; ax[1][1].grid(); 
ax[1][1].legend() ; ax[1][2].grid(); 
ax[1][2].legend() ; ax[2][0].grid(); 
ax[2][1].legend() ; ax[2][1].grid(); 
ax[2][2].legend() ; ax[2][2].grid();

# %%
sol_deg.columns
# Out:
# Index(['dna_X', 'protein_RNAP_machinery', 'protein_sigma_machinery',
#        'protein_NT_units', 'rna_T_X',
#        'complex_protein_RNAP_machinery_protein_sigma_machinery_',
#        'complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_',
#        'protein_Ribo_machinery', 'protein_AA_units0tl',
#        'protein_tRNA_machinery', 'protein_X',
#        'protein_unfolded_protein_degtag', 'protein_Et_machinery',
#        'protein_peptide_chain_peptide', 'protein_protease_machinery',
#        'complex_protein_AA_units0tl_protein_Et_machinery_',
#        'complex_complex_protein_AA_units0tl_protein_Et_machinery__protein_tRNA_machinery_',
#        'complex_protein_AA_units0tl_protein_tRNA_machinery_',
#        'complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_',
#        'complex_protein_protease_machinery_protein_unfolded_protein_degtag_',
#        'complex_protein_X_protein_protease_machinery_',
#        'protein_RNAase_machinery', 'cell_count_count',
#        'complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_',
#        'complex_protein_AA_units0tl_protein_Et_machinery_amp_',
#        'complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_',
#        'complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_',
#        'complex_protein_RNAase_machinery_rna_T_X_', 'time'],
#       dtype='object')

# %%
fig,ax = plt.subplots(nrows = 3, ncols = 3, figsize = (15,10))
# ax.set_title("Growth dependent gene expression")

protease_total = sol_deg['protein_protease_machinery']
protease_total += sol_deg['complex_protein_protease_machinery_protein_unfolded_protein_degtag_']
protease_total += sol_deg['complex_protein_X_protein_protease_machinery_']

deg_complex = sol_deg['complex_protein_protease_machinery_protein_unfolded_protein_degtag_']
deg_complex += sol_deg['complex_protein_X_protein_protease_machinery_']



ax[0][0].plot(timepoints, sol_deg['cell_count_count'], label = "Cell count")
ax[0][1].plot(timepoints, sol_deg['complex_protein_AA_units0tl_protein_Et_machinery_'], label = "tRNA Synthetase-AA complex")
ax[0][2].plot(timepoints, sol_deg['complex_protein_AA_units0tl_protein_Et_machinery_amp_'], label = "tRNA Synthetase-AA-amp complex")
ax[1][0].plot(timepoints, sol_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_'],
label = "tRNA Synthetase-AA-tRNA inactive complex")
ax[1][1].plot(timepoints, sol_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_'],
label = "tRNA Synthetase-AA-tRNA active complex")
ax[1][2].plot(timepoints, sol_deg['complex_protein_AA_units0tl_protein_tRNA_machinery_'], label = "tRNA-AA Complex")
ax[2][0].plot(timepoints,sol_deg['complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_'],
label = "TIC Complex")
ax[2][1].plot(timepoints, protease_total, label = "Total Protease")
ax[2][2].plot(timepoints, deg_complex, label = "Protein-protease Complex")



ax[0][0].legend() ; ax[0][0].grid(); 
ax[0][1].legend() ; ax[0][1].grid(); 
ax[0][2].legend() ; ax[0][2].grid(); 
ax[2][0].legend() ; ax[1][0].grid(); 
ax[1][0].legend() ; ax[1][1].grid(); 
ax[1][1].legend() ; ax[1][2].grid(); 
ax[1][2].legend() ; ax[2][0].grid(); 
ax[2][1].legend() ; ax[2][1].grid(); 
ax[2][2].legend() ; ax[2][2].grid();

# %%
sol_deg.columns
# Out:
# Index(['dna_X', 'protein_RNAP_machinery', 'protein_sigma_machinery',
#        'protein_NT_units', 'rna_T_X',
#        'complex_protein_RNAP_machinery_protein_sigma_machinery_',
#        'complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_',
#        'protein_Ribo_machinery', 'protein_AA_units0tl',
#        'protein_tRNA_machinery', 'protein_X',
#        'protein_unfolded_protein_degtag', 'protein_Et_machinery',
#        'protein_peptide_chain_peptide', 'protein_protease_machinery',
#        'complex_protein_AA_units0tl_protein_Et_machinery_',
#        'complex_complex_protein_AA_units0tl_protein_Et_machinery__protein_tRNA_machinery_',
#        'complex_protein_AA_units0tl_protein_tRNA_machinery_',
#        'complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_',
#        'complex_protein_protease_machinery_protein_unfolded_protein_degtag_',
#        'complex_protein_X_protein_protease_machinery_',
#        'protein_RNAase_machinery', 'cell_count_count',
#        'complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_',
#        'complex_protein_AA_units0tl_protein_Et_machinery_amp_',
#        'complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_',
#        'complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_',
#        'complex_protein_RNAase_machinery_rna_T_X_', 'time'],
#       dtype='object')

# %%
m_deg.get_parameter_dictionary()
# Out:
# {'k_tx_1b__bacterial_transcription': 0.0506,
#  'k_tx_1u__bacterial_transcription': 13.66,
#  'k_tx_2b__bacterial_transcription': 0.000197944,
#  'k_tx_2u__bacterial_transcription': 0.05461,
#  'n__': 5.5,
#  'c_max__logistic_cell_growth': 503666666.666667,
#  'k_tx_3__bacterial_transcription': 0.00232,
#  'k_rnap__bacterial_transcription': 0.024963,
#  'rnap_min__bacterial_transcription': 199.4,
#  'k_tl_1b__bacterial_translation': 0.453,
#  'k_tl_1u__bacterial_translation': 69930.0,
#  'k_tl_2__bacterial_translation': 39960.0,
#  'k_tl_3__bacterial_translation': 9.958,
#  'k_tl_4__bacterial_translation': 590.88,
#  'k_tl_5__bacterial_translation': 138.88,
#  'k_tl_6b__bacterial_translation': 0.00197,
#  'k_tl_6u__bacterial_translation': 742.71,
#  'k_tl_7__bacterial_translation': 3.765,
#  'b_tl_7__bacterial_translation': 1.17,
#  'k_tl_8__bacterial_translation': 0.1,
#  'P_max__bacterial_translation': 31104.0,
#  'b_tl_8__bacterial_translation': 0.5,
#  'k_tRNA__bacterial_translation': 0.0109,
#  'tRNA_min__bacterial_translation': 106.41,
#  'k_ribo__bacterial_translation': 0.0055,
#  'ribo_min__bacterial_translation': 173.15,
#  'k_Et__bacterial_translation': 0.02099,
#  'Et_min__bacterial_translation': 160.8,
#  'k_tl_11__': 0.0005,
#  'k_tl_12__bacterial_translation': 515.476,
#  'k_protease__bacterial_translation': 0.01603749,
#  'protease_min__bacterial_translation': 175.9651,
#  'k_tl_13b__': 6.6885,
#  'k_tl_13u__': 2544.593,
#  'k_tl_9__': 0.1007,
#  'k__logistic_cell_growth': 0.015781,
#  'k_tx_4b__': 2.5497,
#  'k_tx_4u__': 181.72,
#  'b_tx_4u__mrna_degradation': 1.0,
#  'n__mrna_degradation': 5.5,
#  'k_tx_5__': 1.881,
#  'k_tl_10__': 0.001}

# %%
len(list(m_deg.get_parameter_dictionary().values()))
# Out:
# 42

# %% [markdown]
# ### Without deg tag

# %%
# Total rnap, bound and unbound
RNAP_total = sol_no_deg['protein_RNAP_machinery'] + sol_no_deg['complex_protein_RNAP_machinery_protein_sigma_machinery_']  
RNAP_total += sol_no_deg['complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_'] 



# Total DNA, bound and unbound
DNA_total = sol_no_deg['dna_X'] + sol_no_deg['complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_']

# Total sigma, bound and unbound
sigma_total = sol_no_deg['protein_sigma_machinery'] + sol_no_deg['complex_protein_RNAP_machinery_protein_sigma_machinery_'] 
sigma_total += sol_no_deg['complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_'] 

# Total RNAase, bound and unbound
rnaase_total = sol_no_deg['protein_RNAase_machinery'] + sol_no_deg['complex_protein_RNAase_machinery_rna_T_X_']

fig,ax = plt.subplots(nrows = 3, ncols = 3, figsize = (15,10))
ax[0][0].plot(timepoints, sol_no_deg['cell_count_count'], label = "Cell count")
ax[0][1].plot(timepoints, rnaase_total, label = "Total RNAase");ax[0][1].set_ylim(bottom = 0, top = 75)
ax[0][2].plot(timepoints, sol_no_deg['protein_NT_units'], label = "Nucleotide")
ax[1][0].plot(timepoints, RNAP_total, label = "Total RNAP")
ax[1][1].plot(timepoints, DNA_total, label = "Total DNA");ax[1][1].set_ylim(bottom = 0, top = 150)
ax[1][2].plot(timepoints, sol_no_deg['rna_T_X'], label = "mRNA")
ax[2][0].plot(timepoints, sigma_total, label = "Total Sigma"); #ax[2][0].set_ylim(bottom = 0, top = 1500)


ax[0][0].legend() ; ax[0][0].grid(); 
ax[0][1].legend() ; ax[0][1].grid(); 
ax[0][2].legend() ; ax[0][2].grid(); 
ax[2][0].legend() ; ax[1][0].grid(); 
ax[1][0].legend() ; ax[1][1].grid(); 
ax[1][1].legend() ; ax[1][2].grid(); 
ax[1][2].legend() ; ax[2][0].grid(); 
ax[2][1].legend() ; ax[2][1].grid(); 
ax[2][2].legend() ; ax[2][2].grid();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (12,4))

ax[0].plot(timepoints, sol_no_deg['complex_protein_RNAP_machinery_protein_sigma_machinery_'], label = 'Holoenzyme')
ax[1].plot(timepoints, sol_no_deg['complex_complex_protein_RNAP_machinery_protein_sigma_machinery__dna_X_open_'] , label = 'Open Complex')
ax[0].legend(); ax[1].legend(); 
ax[0].grid(); ax[1].grid();

# %%
# Total Ribosome, bound and unbound
ribo_total = sol_no_deg['protein_Ribo_machinery'] 
ribo_total += sol_no_deg['complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_']

# Total tRNA, bound and unbound
tRNA_total = sol_no_deg['protein_tRNA_machinery'] + sol_no_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_']
tRNA_total += sol_no_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_']
tRNA_total += sol_no_deg['complex_protein_AA_units0tl_protein_tRNA_machinery_']
tRNA_total += sol_no_deg['complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_']

# Total mRNA, bound and unbound
mrna_total = sol_no_deg['rna_T_X'] 
mrna_total += sol_no_deg['complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_']
mrna_total += sol_no_deg['complex_protein_RNAase_machinery_rna_T_X_']


# Total tRNA synthetase
synth_total = sol_no_deg['protein_Et_machinery']
synth_total += sol_no_deg['complex_protein_AA_units0tl_protein_Et_machinery_']
synth_total += sol_no_deg['complex_protein_AA_units0tl_protein_Et_machinery_amp_']
synth_total += sol_no_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_']
synth_total += sol_no_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_']


# Total Amino Acid 
aa_total = sol_no_deg['protein_AA_units0tl'] 
aa_total += sol_no_deg['complex_protein_AA_units0tl_protein_Et_machinery_']
aa_total += sol_no_deg['complex_protein_AA_units0tl_protein_Et_machinery_amp_']
aa_total += sol_no_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_']
aa_total += sol_no_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_']
aa_total += sol_no_deg['complex_protein_AA_units0tl_protein_tRNA_machinery_']
aa_total += sol_no_deg['complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_']

fig,ax = plt.subplots(nrows = 3, ncols = 3, figsize = (15,10))
# ax.set_title("Growth dependent gene expression")

ax[0][0].plot(timepoints, sol_no_deg['cell_count_count'], label = "Cell count")
ax[0][1].plot(timepoints, ribo_total, label = "Total Ribosome")
ax[0][2].plot(timepoints, sol_no_deg['protein_AA_units0tl'] , label = "Amino Acid")
ax[1][0].plot(timepoints, synth_total, label = "tRNA-Synthetase")
ax[1][1].plot(timepoints, tRNA_total, label = "Total tRNA")
ax[1][2].plot(timepoints, sol_no_deg['protein_X'], label = "Protein")
ax[2][0].plot(timepoints, sol_no_deg['protein_unfolded_protein_degtag'], label = "Unfolded Protein")
ax[2][1].plot(timepoints, mrna_total, label = "Total mRNA")
ax[2][2].plot(timepoints, sol_no_deg['protein_peptide_chain_peptide'], label = "Peptide")


ax[0][0].legend() ; ax[0][0].grid(); 
ax[0][1].legend() ; ax[0][1].grid(); 
ax[0][2].legend() ; ax[0][2].grid(); 
ax[2][0].legend() ; ax[1][0].grid(); 
ax[1][0].legend() ; ax[1][1].grid(); 
ax[1][1].legend() ; ax[1][2].grid(); 
ax[1][2].legend() ; ax[2][0].grid(); 
ax[2][1].legend() ; ax[2][1].grid(); 
ax[2][2].legend() ; ax[2][2].grid();

# %%
fig,ax = plt.subplots(nrows = 3, ncols = 3, figsize = (15,10))
# ax.set_title("Growth dependent gene expression")

ax[0][0].plot(timepoints, sol_no_deg['cell_count_count'], label = "Cell count")
ax[0][1].plot(timepoints, sol_no_deg['complex_protein_AA_units0tl_protein_Et_machinery_'], label = "tRNA Synthetase-AA complex")
ax[0][2].plot(timepoints, sol_no_deg['complex_protein_AA_units0tl_protein_Et_machinery_amp_'], label = "tRNA Synthetase-AA-amp complex")
ax[1][0].plot(timepoints, sol_no_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_inactive_'],
label = "tRNA Synthetase-AA-tRNA inactive complex")
ax[1][1].plot(timepoints, sol_no_deg['complex_complex_protein_AA_units0tl_protein_Et_machinery_amp__protein_tRNA_machinery_active_'],
label = "tRNA Synthetase-AA-tRNA active complex")
ax[1][2].plot(timepoints, sol_no_deg['complex_protein_AA_units0tl_protein_tRNA_machinery_'], label = "tRNA-AA Complex")
ax[2][0].plot(timepoints,sol_no_deg['complex_complex_protein_AA_units0tl_protein_tRNA_machinery__protein_Ribo_machinery_rna_T_X_'],
label = "TIC Complex")
# ax[2][1].plot(timepoints, R['complex_protein_protease_machinery_protein_unfolded_protein_degtag_'], 
#               label = "Unfolded Protein-Protease Complex")
# ax[2][2].plot(timepoints, R['complex_protein_RNAase_machinery_rna_T_X_'], label = "mRNA-RNAase Complex")



ax[0][0].legend() ; ax[0][0].grid(); 
ax[0][1].legend() ; ax[0][1].grid(); 
ax[0][2].legend() ; ax[0][2].grid(); 
ax[2][0].legend() ; ax[1][0].grid(); 
ax[1][0].legend() ; ax[1][1].grid(); 
ax[1][1].legend() ; ax[1][2].grid(); 
ax[1][2].legend() ; ax[2][0].grid(); 
ax[2][1].legend() ; ax[2][1].grid(); 
ax[2][2].legend() ; ax[2][2].grid();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
